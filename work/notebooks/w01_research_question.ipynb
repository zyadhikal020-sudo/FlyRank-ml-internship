# %% [markdown]
# <a href="https://colab.research.google.com/github/zyadhikal020-sudo/FlyRank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zyadhikal020-sudo/FlyRank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Refresh / Content Opportunity Scoring**-I chose the **Refresh / Content Opportunity Scoring** lane because my role is to support the SEO team, not replace it. Large websites may contain thousands of webpages, making manual review difficult and time-consuming. A scoring model can rank pages based on their opportunity for review, helping the SEO team focus on the highest-priority pages first. The final decision remains with the SEO experts, while the model helps reduce time and effort.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# Which webpages should be reviewed first to help the SEO team focus on the pages with the highest opportunity?
#
# ## Decision
#
# Help the SEO team prioritize which webpages should be reviewed first instead of manually checking thousands of pages.
#
# ## Action
#
# The model produces a ranked list of webpages with priority scores and recommendation reasons. The SEO team reviews these recommendations, investigates the root cause, and decides the appropriate action.
#
# ## Cost of a Wrong Recommendation
#
# If the ranking is inaccurate, the team may spend time reviewing low-priority pages while missing pages that actually need attention. This reduces efficiency and delays content improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Dataset shape:", df.shape)
print("Average impressions:", round(df["impressions_90d"].mean(), 2))
print("Average clicks:", round(df["clicks_90d"].mean(), 2))
print("Average sessions:", round(df["sessions_90d"].mean(), 2))
# Out:
# Number of pages: 30000
# Dataset shape: (30000, 44)
# Average impressions: 5200.37
# Average clicks: 16.1
# Average sessions: 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support based on historical data and observed patterns. It helps prioritize webpages that may deserve review, but it does not replace human judgment.
#
# The results are directional recommendations, not guarantees. This project cannot explain the exact reason behind ranking changes, predict Google's algorithm, or guarantee that refreshing a page will improve search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
